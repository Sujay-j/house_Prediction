# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import glob

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization,Conv2D,MaxPooling2D,Activation
from tensorflow.keras.layers import Dropout,Dense,Flatten,Input
from tensorflow.keras.models import Model

# %%
def load_house_images(df,inputPath):
    images = []
    for i in df.index.values:
        basePath = os.path.sep.join([inputPath, "{}_*".format(i + 1)])
        housePaths = sorted(list(glob.glob(basePath)))
        inputImages = []
        outputImages =np.zeros((64,64,3),dtype = "uint8")
        for housePath in housePaths:
            image = cv2.imread(housePath)
            image = cv2.resize(image,(32,32))
            inputImages.append(image)
        outputImages[0:32,0:32]=inputImages[0]
        outputImages[0:32,32:64]=inputImages[1]
        outputImages[32:64,32:64]=inputImages[2]
        outputImages[32:64,0:32]=inputImages[3]
        images.append(outputImages)
            
    return np.array(images)

# %%
def create_cnn(width,height,depth,filters=(16,32,64),regress = False):
    inputShape = (height,width,depth)
    chanDim = -1
    inputs = Input(shape = inputShape)
    for (i,f) in enumerate(filters):
        if i == 0:
            x= inputs
        x=Conv2D(f,(3,3),padding="same")(x)
        x=Activation("relu")(x)
        x=BatchNormalization(axis=chanDim)(x)
        x=MaxPooling2D(pool_size=(2,2))(x)
    x=Flatten()(x)
    x=Dense(16)(x)
    x=Activation("relu")(x)
    x=BatchNormalization(axis=chanDim)(x)
    x=Dropout(0.5)(x)
    
    x=Dense(4)(x)
    x=Activation("relu")(x)
    
    if regress:
        x=Dense(1,activation="linear")(x)
        
    model = Model(inputs,x)
    return model

# %%
def load_house_attributes(inputPath):
	# initialize the list of column names in the CSV file and then
	# load it using Pandas
	cols = ["bedrooms", "bathrooms", "area", "zipcode", "price"]
	df = pd.read_csv(inputPath, sep=" ", header=None, names=cols)

	# determine (1) the unique zip codes and (2) the number of data
	# points with each zip code
	zipcodes = df["zipcode"].value_counts().keys().tolist()
	counts = df["zipcode"].value_counts().tolist()

	# loop over each of the unique zip codes and their corresponding
	# count
	for (zipcode, count) in zip(zipcodes, counts):
		# the zip code counts for our housing dataset is *extremely*
		# unbalanced (some only having 1 or 2 houses per zip code)
		# so let's sanitize our data by removing any houses with less
		# than 25 houses per zip code
		if count < 25:
			idxs = df[df["zipcode"] == zipcode].index
			df.drop(idxs, inplace=True)

	# return the data frame
	return df

# %%
def process_house_attributes(df, train, test):
	# initialize the column names of the continuous data
	continuous = ["bedrooms", "bathrooms", "area"]

	# performin min-max scaling each continuous feature column to
	# the range [0, 1]
	cs = MinMaxScaler()
	trainContinuous = cs.fit_transform(train[continuous])
	testContinuous = cs.transform(test[continuous])

	# one-hot encode the zip code categorical data (by definition of
	# one-hot encoing, all output features are now in the range [0, 1])
	zipBinarizer = LabelBinarizer().fit(df["zipcode"])
	trainCategorical = zipBinarizer.transform(train["zipcode"])
	testCategorical = zipBinarizer.transform(test["zipcode"])

	# construct our training and testing data points by concatenating
	# the categorical features with the continuous features
	trainX = np.hstack([trainCategorical, trainContinuous])
	testX = np.hstack([testCategorical, testContinuous])

	# return the concatenated training and testing data
	return (trainX, testX)

# %%
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
import locale
import cv2

# %%
dataset = os.getcwd()

# %%
print(type(dataset))
dataset
# Out:
# <class 'str'>
# 'C:\\Users\\Sujay J\\Desktop\\PYImage\\my exersize\\house_prediction\\Houses-dataset-master\\Houses Dataset'

# %%
inputPath = os.path.sep.join([dataset,"HousesInfo.txt"])
#inputpath=os.path.

# %%
df =load_house_attributes(inputPath)

# %%
images = load_house_images(df,dataset)
images = images/255.0

# %%
split = train_test_split(df, images, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

# %%
import matplotlib.pyplot as plt
#plt.imshow(images[13])
images.shape
# Out:
# (362, 64, 64, 3)

# %%
maxPrice = trainAttrX["price"].max()
trainY = trainAttrX["price"] / maxPrice
testY = testAttrX["price"] / maxPrice

# %%
trainY = np.asarray(trainY)
testY = np.asarray(testY)

# %%
type(trainY)
# Out:
# numpy.ndarray

# %%
model = create_cnn(64, 64, 3, regress=True)
opt = Adam(lr=1e-3,decay = 1e-3/200)
model.compile(loss = "mean_absolute_percentage_error",optimizers = opt)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                65552
# _________________________________________________________________
# activation_8 (Activation)    (None, 16)                0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16)                64
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 68
# _________________________________________________________________
# activation_9 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 89,721
# Trainable params: 89,465
# Non-trainable params: 256
# _________________________________________________________________

# %%
model.fit(x=trainImagesX, y=trainY, 
    validation_data=(testImagesX, testY),
    epochs=200, batch_size=8)
# Out:
# Train on 271 samples, validate on 91 samples
# Epoch 1/200
# 271/271 [==============================] - 7s 27ms/sample - loss: 1146.2553 - val_loss: 1710.9222
# Epoch 2/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 777.4776 - val_loss: 988.1495
# Epoch 3/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 607.2016 - val_loss: 514.8261
# Epoch 4/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 432.6380 - val_loss: 899.8729
# Epoch 5/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 332.2768 - val_loss: 3082.5206
# Epoch 6/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 313.9893 - val_loss: 4913.9156
# Epoch 7/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 276.8018 - val_loss: 4026.1384
# Epoch 8/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 218.0217 - val_loss: 1341.0931
# Epoch 9/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 201.8982 - val_loss: 743.7911
# Epoch 10/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 185.0220 - val_loss: 603.2354
# Epoch 11/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 138.9900 - val_loss: 741.3946
# Epoch 12/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 145.9893 - val_loss: 472.6607
# Epoch 13/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 105.2092 - val_loss: 646.3489
# Epoch 14/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 90.9998 - val_loss: 1481.4231
# Epoch 15/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 86.3080 - val_loss: 1695.0580
# Epoch 16/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 96.8820 - val_loss: 68.5659
# Epoch 17/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 77.5556 - val_loss: 71.7372
# Epoch 18/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 74.8058 - val_loss: 109.3419
# Epoch 19/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 69.9195 - val_loss: 70.9507
# Epoch 20/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 68.9862 - val_loss: 71.0740
# Epoch 21/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 68.4160 - val_loss: 71.2184
# Epoch 22/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 67.5273 - val_loss: 71.7660
# Epoch 23/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 67.8099 - val_loss: 72.3787
# Epoch 24/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 69.8798 - val_loss: 71.0685
# Epoch 25/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 65.7480 - val_loss: 70.2909
# Epoch 26/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 73.5208 - val_loss: 70.0077
# Epoch 27/200
# 271/271 [==============================] - 1s 3ms/sample - loss: 68.1133 - val_loss: 69.8490
# Epoch 28/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 66.6073 - val_loss: 69.6953
# Epoch 29/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 65.2323 - val_loss: 68.5955
# Epoch 30/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 66.6376 - val_loss: 69.0557
# Epoch 31/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 69.2830 - val_loss: 69.7939
# Epoch 32/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 65
200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.3422 - val_loss: 64.9885
# Epoch 151/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.4017 - val_loss: 56.2919
# Epoch 152/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.1387 - val_loss: 54.3973
# Epoch 153/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.2606 - val_loss: 56.4409
# Epoch 154/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.5914 - val_loss: 53.9220
# Epoch 155/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 40.4601 - val_loss: 65.3322
# Epoch 156/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.2475 - val_loss: 63.6318
# Epoch 157/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.2958 - val_loss: 58.8888
# Epoch 158/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.9111 - val_loss: 50.8312
# Epoch 159/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.6709 - val_loss: 51.5779
# Epoch 160/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.6322 - val_loss: 49.5924
# Epoch 161/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 47.1060 - val_loss: 54.5768
# Epoch 162/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.8578 - val_loss: 50.6465
# Epoch 163/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 45.2745 - val_loss: 52.9672
# Epoch 164/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 45.8038 - val_loss: 56.0481
# Epoch 165/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 47.7093 - val_loss: 65.5809
# Epoch 166/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.5509 - val_loss: 57.2218
# Epoch 167/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 40.6689 - val_loss: 56.0219
# Epoch 168/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.9222 - val_loss: 75.2501
# Epoch 169/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.1445 - val_loss: 93.1565
# Epoch 170/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.6795 - val_loss: 65.9647
# Epoch 171/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.1660 - val_loss: 166.5221
# Epoch 172/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.8360 - val_loss: 55.0727
# Epoch 173/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.0084 - val_loss: 56.3169
# Epoch 174/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 40.0276 - val_loss: 57.3322
# Epoch 175/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 38.6998 - val_loss: 54.5656
# Epoch 176/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.3717 - val_loss: 55.2268
# Epoch 177/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.7820 - val_loss: 52.5158
# Epoch 178/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.4820 - val_loss: 53.3494
# Epoch 179/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 43.2084 - val_loss: 53.5375
# Epoch 180/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 40.6367 - val_loss: 52.6896
# Epoch 181/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 40.6628 - val_loss: 53.8903
# Epoch 182/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.5133 - val_loss: 52.6891
# Epoch 183/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.6071 - val_loss: 54.7344
# Epoch 184/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.7173 - val_loss: 53.1253
# Epoch 185/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.6092 - val_loss: 49.8641
# Epoch 186/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.0466 - val_loss: 79.8211
# Epoch 187/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.1317 - val_loss: 73.4042
# Epoch 188/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 45.7638 - val_loss: 57.9070
# Epoch 189/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 44.2909 - val_loss: 54.7227
# Epoch 190/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.3676 - val_loss: 54.0735
# Epoch 191/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.0771 - val_loss: 53.0691
# Epoch 192/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.4024 - val_loss: 165.7923
# Epoch 193/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.3132 - val_loss: 61.7072
# Epoch 194/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.0862 - val_loss: 82.7158
# Epoch 195/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.4169 - val_loss: 51.3938
# Epoch 196/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.7867 - val_loss: 51.3209
# Epoch 197/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 39.0969 - val_loss: 56.7460
# Epoch 198/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.8696 - val_loss: 55.0129
# Epoch 199/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 41.6060 - val_loss: 334.0104
# Epoch 200/200
# 271/271 [==============================] - 1s 4ms/sample - loss: 42.4144 - val_loss: 70.4468

# %%
preds = model.predict(testImagesX)

# %%
diff = preds.flatten()-testY
percentageDiff = (diff / testY) * 100
absPrecentDiff = np.abs(percentageDiff)

# %%
mean = np.mean(absPrecentDiff)
std = np.std(absPrecentDiff)

# %%
locale.setlocale(locale.LC_ALL, "en_US.UTF-8")
print("[INFO] avg. house price: {}, std house price: {}".format(
	locale.currency(df["price"].mean(), grouping=True),
	locale.currency(df["price"].std(), grouping=True)))
print("[INFO] mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# [INFO] avg. house price: $533,388.27, std house price: $493,403.08
# [INFO] mean: 70.45%, std: 159.64%
